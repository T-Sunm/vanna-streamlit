# %% [markdown]
# ### Import data and library

# %%
import pandas as pd
import re
file_path = "../ingest_data/raw/Danh mục các học phần giảng dạy_HKI_25-26.xlsx"

# %%
df = pd.read_excel(file_path, sheet_name="Sheet1")
df
# Out:
#      DANH MỤC HỌC PHẦN GIẢNG DẠY HỌC KỲ 1 NĂM HỌC 2025-2026  \
# 0                                                   NaN
# 1                             A. KHOA KHOA HỌC MÁY TÍNH
# 2                  1. Ngành Công nghệ thông tin (Kỹ sư)
# 3     1.1. Ngành Công nghệ thông tin - Khóa 2019 (kỳ...
# 4                                                   STT
# ...                                                 ...
# 1108                                                  5
# 1109                                                  6
# 1110                                                  7
# 1111                                                  8
# 1112                                                NaN
#
#                  Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                       NaN         NaN        NaN        NaN        NaN
# 1                       NaN         NaN        NaN        NaN        NaN
# 2                       NaN         NaN        NaN        NaN        NaN
# 3                       NaN         NaN        NaN        NaN        NaN
# 4              Tên học phần  Số tín chỉ        NaN        NaN    Ghi chú
# ...                     ...         ...        ...        ...        ...
# 1108    Giáo dục thể chất 1           0          1          1        NaN
# 1109          Kinh tế vi mô           3          0          3        NaN
# 1110      Marketing căn bản           3          0          3        NaN
# 1111  Lập trình Python (BA)         2.5        0.5          3        NaN
# 1112                   TỔNG        17.5        2.5         20        NaN
#
#      Unnamed: 6
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 1108       25EF
# 1109       25EF
# 1110       25EF
# 1111       25EF
# 1112        NaN
#
# [1113 rows x 7 columns]

# %% [markdown]
# ### Preprocessing data

# %%
title = df.columns[0]
print(f"Tiêu đề gốc: {title}")

# --- Bước 2: Dùng Regex để trích xuất thông tin ---
# Tìm "học kỳ X"
match_hk = re.search(r'HỌC KỲ (\d+)', title, re.IGNORECASE)
hoc_ky = match_hk.group(0) if match_hk else "Không tìm thấy học kỳ"

# Tìm "năm học YYYY-YYYY" và chỉ lấy phần năm
match_nh = re.search(r'NĂM HỌC (\d{4}-\d{4})', title, re.IGNORECASE)
nam_hoc = match_nh.group(1) if match_nh else "Không tìm thấy năm học" # .group(1) để lấy phần trong ngoặc

print(f"Học kỳ đã trích xuất: {hoc_ky}")
print(f"Năm học đã trích xuất: {nam_hoc}")

# --- Bước 3: Làm sạch DataFrame ---
# 3.1. Lấy hàng thứ 5 (index=4) làm header mới cho DataFrame
df.columns = df.iloc[4]

# 3.2. Xóa 5 hàng đầu tiên (từ index 0 đến 4)
df = df.iloc[5:].reset_index(drop=True)

# Hiển thị DataFrame sau khi đã làm sạch
print("\nDataFrame sau khi làm sạch:")
df
# Out:
# Tiêu đề gốc: DANH MỤC HỌC PHẦN GIẢNG DẠY HỌC KỲ 1 NĂM HỌC 2025-2026
# Học kỳ đã trích xuất: HỌC KỲ 1
# Năm học đã trích xuất: 2025-2026
#
# DataFrame sau khi làm sạch:
# 4                                                   STT  \
# 0                                                   NaN
# 1                                                     1
# 2                                                     2
# 3                                                   NaN
# 4     1.2. Ngành Công nghệ thông tin - Khóa 2021 (kỳ...
# ...                                                 ...
# 1103                                                  5
# 1104                                                  6
# 1105                                                  7
# 1106                                                  8
# 1107                                                NaN
#
# 4                 Tên học phần Số tín chỉ  NaN   NaN Ghi chú  \
# 0                          NaN         LT   TH  Tổng     NaN
# 1     Thực tập tốt nghiệp (IT)          0    3     3     NaN
# 2        Đồ án tốt nghiệp (IT)          0   10    10     NaN
# 3                         TỔNG          0   13    13     NaN
# 4                          NaN        NaN  NaN   NaN     NaN
# ...                        ...        ...  ...   ...     ...
# 1103       Giáo dục thể chất 1          0    1     1     NaN
# 1104             Kinh tế vi mô          3    0     3     NaN
# 1105         Marketing căn bản          3    0     3     NaN
# 1106     Lập trình Python (BA)        2.5  0.5     3     NaN
# 1107                      TỔNG       17.5  2.5    20     NaN
#
# 4                                             NaN
# 0                                             NaN
# 1     19GIT,19SE1->SE5,19JIT,19KIT,19AD,19DA,19MC
# 2     19GIT,19SE1->SE5,19JIT,19KIT,19AD,19DA,19MC
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 1103                                         25EF
# 1104                                         25EF
# 1105                                         25EF
# 1106                                         25EF
# 1107                                          NaN
#
# [1108 rows x 7 columns]

# %%
df = df.drop("STT", axis=1)
column_list = df.columns.tolist()
column_list[0] = 'ten_hp'  
column_list[1] = 'lt' 
column_list[2] = 'th' 
column_list[3] = 'tong'
column_list[4] = 'ghi_chu'
column_list[5] = 'lop'
df.columns = column_list
df
# Out:
#                         ten_hp    lt   th  tong ghi_chu  \
# 0                          NaN    LT   TH  Tổng     NaN
# 1     Thực tập tốt nghiệp (IT)     0    3     3     NaN
# 2        Đồ án tốt nghiệp (IT)     0   10    10     NaN
# 3                         TỔNG     0   13    13     NaN
# 4                          NaN   NaN  NaN   NaN     NaN
# ...                        ...   ...  ...   ...     ...
# 1103       Giáo dục thể chất 1     0    1     1     NaN
# 1104             Kinh tế vi mô     3    0     3     NaN
# 1105         Marketing căn bản     3    0     3     NaN
# 1106     Lập trình Python (BA)   2.5  0.5     3     NaN
# 1107                      TỔNG  17.5  2.5    20     NaN
#
#                                               lop
# 0                                             NaN
# 1     19GIT,19SE1->SE5,19JIT,19KIT,19AD,19DA,19MC
# 2     19GIT,19SE1->SE5,19JIT,19KIT,19AD,19DA,19MC
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 1103                                         25EF
# 1104                                         25EF
# 1105                                         25EF
# 1106                                         25EF
# 1107                                          NaN
#
# [1108 rows x 6 columns]

# %%
import re
import pandas as pd

def expand_lop(token):
    """
    Mở rộng một token lớp, ví dụ:
    "19SE1->SE5" -> ["19SE1", "19SE2", "19SE3", "19SE4", "19SE5"]
    "22SE1->2" -> ["22SE1", "22SE2"]
    """
    token = token.strip()
    if "->" not in token:
        return [token]

    left, right = token.split("->")
    left = left.strip()
    right = right.strip()

    # Lấy tiền tố và số bắt đầu từ bên trái
    match_left = re.match(r"([a-zA-Z0-9_]*?)(\d+)$", left)
    if not match_left:
        return [token]
    
    prefix_to_use, start_num_str = match_left.groups()
    start_num = int(start_num_str)
    
    end_num = 0

    # Xử lý bên phải
    if right.isdigit():
        # Trường hợp bên phải chỉ là số: "22SE1->2"
        end_num = int(right)
    else:
        # Trường hợp bên phải có cả tiền tố: "19SE1->SE5"
        match_right = re.match(r"([a-zA-Z0-9_]*?)(\d+)$", right)
        if not match_right:
            return [token]
        
        prefix_right, end_num_str = match_right.groups()
        end_num = int(end_num_str)
        
        # Chỉ kiểm tra hậu tố thay vì toàn bộ tiền tố
        if not prefix_to_use.endswith(prefix_right):
            return [token]

    if end_num < start_num:
        return [token]

    return [f"{prefix_to_use}{i}" for i in range(start_num, end_num + 1)]

def get_cohort_and_classes(token):
    """
    Mở rộng token lớp và trả về cả khóa và danh sách các lớp.
    Ví dụ: "19SE1->SE5" -> (19, ["19SE1", "19SE2", ...])
    """
    # 1. Lấy danh sách lớp từ hàm gốc
    expanded_classes = expand_lop(token)
    
    cohort = None
    # 2. Nếu có kết quả, dùng regex để lấy số đầu tiên làm khóa
    if expanded_classes and expanded_classes[0]:
        first_class = expanded_classes[0]
        cohort_match = re.match(r"(\d+)", first_class)
        if cohort_match:
            cohort = int(cohort_match.group(1))
            
    # 3. Trả về kết quả
    return (cohort, expanded_classes)

result = {"academic_year": nam_hoc, "semester": {}}

for idx, row in df.iterrows():
    # --- DÒNG THÊM VÀO ĐỂ SỬA LỖI ---
    # Kiểm tra xem key hoc_ky (ví dụ: "semester_1") đã có trong "semester" chưa
    # Nếu chưa có, tạo nó là một dictionary rỗng.
    if hoc_ky not in result["semester"]:
        result["semester"][hoc_ky] = {}
    # ------------------------------------

    lop_raw = str(row["lop"]).split(",") if pd.notna(row["lop"]) else []
    for token in lop_raw:
        token = token.strip()
        if not token or token == "nan":
            continue
        cohort, classes = get_cohort_and_classes(token)
        for class_name in classes:
            if cohort not in result["semester"][hoc_ky]:
                result["semester"][hoc_ky][cohort] = {}
            if class_name not in result["semester"][hoc_ky][cohort]:
                result["semester"][hoc_ky][cohort][class_name] = []
            
            result["semester"][hoc_ky][cohort][class_name].append({
                "course_name": row["ten_hp"],
                "lt": float(row["lt"]) if pd.notna(row["lt"]) else 0,
                "th": float(row["th"]) if pd.notna(row["th"]) else 0,
                "tong": float(row["tong"]) if pd.notna(row["tong"]) else 0,
                "subnote": row["ghi_chu"] if pd.notna(row["ghi_chu"]) else None
            })

# %%
result
# Out:
# {'academic_year': '2025-2026',
#  'semester': {'HỌC KỲ 1': {19: {'19GIT': [{'course_name': 'Thực tập tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 10.0,
#       'tong': 10.0,
#       'subnote': None}],
#     '19SE1': [{'course_name': 'Thực tập tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 10.0,
#       'tong': 10.0,
#       'subnote': None}],
#     '19SE2': [{'course_name': 'Thực tập tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 10.0,
#       'tong': 10.0,
#       'subnote': None}],
#     '19SE3': [{'course_name': 'Thực tập tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 10.0,
#       'tong': 10.0,
#       'subnote': None}],
#     '19SE4': [{'course_name': 'Thực tập tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 10.0,
#       'tong': 10.0,
#       'subnote': None}],
#     '19SE5': [{'course_name': 'Thực tập tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 10.0,
#       'tong': 10.0,
#       'subnote': None}],
#     '19JIT': [{'course_name': 'Thực tập tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 10.0,
#       'tong': 10.0,
#       'subnote': None}],
#     '19KIT': [{'course_name': 'Thực tập tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 10.0,
#       'tong': 10.0,
#       'subnote': None}],
#     '19AD': [{'course_name': 'Thực tập tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 10.0,
#       'tong': 10.0,
#       'subnote': None}],
#     '19DA': [{'course_name': 'Thực tập tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 10.0,
#       'tong': 10.0,
#       'subnote': None}],
#     '19MC': [{'course_name': 'Thực tập tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 10.0,
#       'tong': 10.0,
#       'subnote': None}]},
#    21: {'21GIT': [{'course_name': 'Thực tập tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 10.0,
#       'tong': 10.0,
#       'subnote': None}],
#     '21SE1': [{'course_name': 'Thực tập tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 10.0,
#       'tong': 10.0,
#       'subnote': None}],
#     '21SE2': [{'course_name': 'Thực tập tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 10.0,
#       'tong': 10.0,
#       'subnote': None}],
#     '21SE3': [{'course_name': 'Thực tập tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 10.0,
#       'tong': 10.0,
#       'subnote': None}],
#     '21SE4': [{'course_name': 'Thực tập tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 10.0,
#       'tong': 10.0,
#       'subnote': None}],
#     '21SE5': [{'course_name': 'Thực tập tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 10.0,
#       'tong': 10.0,
#       'subnote': None}],
#     '21JIT': [{'course_name': 'Thực tập tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 10.0,
#       'tong': 10.0,
#       'subnote': None}],
#     '21KIT': [{'course_name': 'Thực tập tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 10.0,
#       'tong': 10.0,
#       'subnote': None}],
#     '21AD': [{'course_name': 'Thực tập tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 10.0,
#       'tong': 10.0,
#       'subnote': None}],
#     '21DA': [{'course_name': 'Thực tập tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 10.0,
#       'tong': 10.0,
#       'subnote': None}],
#     '21MC': [{'course_name': 'Thực tập tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 10.0,
#       'tong': 10.0,
#       'subnote': None}],
#     '21CE1': [{'course_name': 'Thực tập tốt nghiệp (CE)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án tốt nghiệp (CE)',
#       'lt': 0.0,
#       'th': 10.0,
#       'tong': 10.0,
#       'subnote': None}],
#     '21CE2': [{'course_name': 'Thực tập tốt nghiệp (CE)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án tốt nghiệp (CE)',
#       'lt': 0.0,
#       'th': 10.0,
#       'tong': 10.0,
#       'subnote': None}],
#     '21IR': [{'course_name': 'Thực tập tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 10.0,
#       'tong': 10.0,
#       'subnote': None}],
#     '21NS': [{'course_name': 'Thực tập tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án tốt nghiệp (IT)',
#       'lt': 0.0,
#       'th': 10.0,
#       'tong': 10.0,
#       'subnote': None}]},
#    22: {'22SE1': [{'course_name': 'Kinh tế chính trị Mác - Lênin',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tư tưởng Hồ Chí Minh',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Đảm bảo chất lượng và Kiểm thử phần mềm',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Điện toán đám mây',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Chuyên đề 3 (IT)',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': 'Low code, No code & Automation'},
#      {'course_name': 'Đồ án chuyên ngành 2 (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Phát triển ứng dụng di động đa nền tảng',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Lập trình game',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Kho dữ liệu',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Thực tập doanh nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None}],
#     '22SE2': [{'course_name': 'Kinh tế chính trị Mác - Lênin',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tư tưởng Hồ Chí Minh',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Đảm bảo chất lượng và Kiểm thử phần mềm',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Điện toán đám mây',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Chuyên đề 3 (IT)',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': 'Low code, No code & Automation'},
#      {'course_name': 'Đồ án chuyên ngành 2 (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Phát triển ứng dụng di động đa nền tảng',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Lập trình game',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Kho dữ liệu',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Thực tập doanh nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None}],
#     '22GIT-KS': [{'course_name': 'Kinh tế chính trị Mác - Lênin',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tư tưởng Hồ Chí Minh',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Đảm bảo chất lượng và Kiểm thử phần mềm',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Điện toán đám mây',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Chuyên đề 3 (IT)',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': 'AI-Data Science Projects'},
#      {'course_name': 'Đồ án chuyên ngành 2',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Phát triển ứng dụng di động đa nền tảng',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Lập trình game',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Kho dữ liệu',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Thực tập doanh nghiệp',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None}],
#     '22JIT': [{'course_name': 'Kinh tế chính trị Mác - Lênin',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tư tưởng Hồ Chí Minh',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Đảm bảo chất lượng và Kiểm thử phần mềm',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Điện toán đám mây',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Chuyên đề 3 (IT)',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': 'Blockchain'},
#      {'course_name': 'Đồ án chuyên ngành 2 (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Phát triển ứng dụng di động đa nền tảng',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Nhật nâng cao 1',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Thực tập doanh nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None}],
#     '22KIT-KS': [{'course_name': 'Kinh tế chính trị Mác - Lênin',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tư tưởng Hồ Chí Minh',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Đảm bảo chất lượng và Kiểm thử phần mềm',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Điện toán đám mây',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Chuyên đề 3 (IT)',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': 'Blockchain'},
#      {'course_name': 'Đồ án chuyên ngành 2 (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Phát triển ứng dụng di động đa nền tảng',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Hàn doanh nghiệp 3',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Thực tập doanh nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None}],
#     '22AD': [{'course_name': 'Kinh tế chính trị Mác - Lênin',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tư tưởng Hồ Chí Minh',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Học sâu',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Phân tích dữ liệu',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Thị giác máy tính',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Chuyên đề 3 (IT)',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': 'Sentiment analysis'},
#      {'course_name': 'Đồ án chuyên ngành 2 (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Thực tập doanh nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None}],
#     '22MC': [{'course_name': 'Kinh tế chính trị Mác - Lênin',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tư tưởng Hồ Chí Minh',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Chương trình dịch',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Lập trình Game',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Thiết kế nhân vật 2 chiều',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Chuyên đề 3 (IT)',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': 'Quy trình sản xuất phim và Game'},
#      {'course_name': 'Đồ án chuyên ngành 2 (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Truyền thông đại chúng ứng dụng',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Thiết kế Poster',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Thực tập doanh nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None}],
#     '22DA': [{'course_name': 'Kinh tế chính trị Mác –Lênin',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tư tưởng Hồ Chí Minh',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Chương trình dịch',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Trí tuệ nhân tạo',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Chuyên đề 3 (IT)',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': 'Chất liệu tạo hình'},
#      {'course_name': 'Đồ án chuyên ngành 2 (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Thiết kế Logo',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Thiết kế bộ ấn phẩm văn phòng',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Thiết kế hoạt hình 2 chiều',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Thực tập doanh nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None}],
#     '22GIT-CN': [{'course_name': 'Chủ nghĩa xã hội khoa học',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Lịch sử Đảng Cộng sản Việt Nam',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Quản trị dự án phần mềm',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Phân tích và thiết kế giải thuật',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Thiết kế UX/UI',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Chuyên đề 3 (IT)',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': 'AI-Data Science Projects/ Hệ khuyến nghị'},
#      {'course_name': 'Đồ án chuyên ngành 2 (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Bảo mật và An toàn hệ thống thông tin',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None}],
#     '22SE1B->2B': [{'course_name': 'Chủ nghĩa xã hội khoa học',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Lịch sử Đảng Cộng sản Việt Nam',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Quản trị dự án phần mềm',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Phân tích và thiết kế giải thuật',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Thiết kế UX/UI',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Chuyên đề 3 (IT)',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': 'AI-Data Science Projects/ Hệ khuyến nghị'},
#      {'course_name': 'Đồ án chuyên ngành 2 (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Bảo mật và An toàn hệ thống thông tin',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None}],
#     '22KIT-CN': [{'course_name': 'Chủ nghĩa xã hội khoa học',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Lịch sử Đảng Cộng sản Việt Nam',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Quản trị dự án phần mềm',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Thiết kế UX/UI',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Đồ án chuyên ngành 2 (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Phát triển ứng dụng di động đa nền tảng',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Hàn doanh nghiệp 3',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None}],
#     '22MCB': [{'course_name': 'Chủ nghĩa xã hội khoa học',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Lịch sử Đảng Cộng sản Việt Nam',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Thiết kế nhân vật 3 chiều',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Chuyên đề 3 (IT)',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': 'Quy trình sản xuất phim và Game'},
#      {'course_name': 'Đồ án chuyên ngành 2 (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Biên tập phim kỹ thuật số',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Kịch bản truyền thông',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Thiết kế hình hiệu (TV intro)',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None}],
#     '22ITe': [{'course_name': 'Chủ nghĩa xã hội khoa học',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Lịch sử Đảng Cộng sản Việt Nam',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Quản trị dự án phần mềm',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Phân tích và thiết kế giải thuật',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Thiết kế UX/UI',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Chuyên đề 3 (IT)',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': 'Blockchain'},
#      {'course_name': 'Đồ án chuyên ngành 2 (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Bảo mật và An toàn hệ thống thông tin',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None}],
#     '22ES-KS': [{'course_name': 'Kinh tế chính trị Mác - Lênin',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tư tưởng Hồ Chí Minh',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Chương trình dịch',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Chuyên đề 3 (CE)',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': 'Lập trình ô tô'},
#      {'course_name': 'Đồ án chuyên ngành 2 (CE)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Thực tập doanh nghiệp (CE)',
#       'lt': 0.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Thiết kế VLSI',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Lập trình Python cho hệ thống nhúng',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None}],
#     '22IC-KS': [{'course_name': 'Kinh tế chính trị Mác - Lênin',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tư tưởng Hồ Chí Minh',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Chương trình dịch',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Thiết kế IC số',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Thực tập doanh nghiệp (CE)',
#       'lt': 0.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Thiết kế VLSI',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án thiết kế 1 (CE)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Lập trình Python cho hệ thống nhúng',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None}],
#     '22ES-CN': [{'course_name': 'Chủ nghĩa xã hội khoa học',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Lịch sử Đảng cộng sản Việt Nam',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Lập trình Python cho hệ thống nhúng',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Thị giác máy tính',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án chuyên ngành 2 (CE)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Thiết kế IC tương tự',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None}],
#     '22IC-CN': [{'course_name': 'Chủ nghĩa xã hội khoa học',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Lịch sử Đảng cộng sản Việt Nam',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Lập trình Python cho hệ thống nhúng',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án chuyên ngành 2 (CE)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Thiết kế IC tương tự',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Thiết kế VLSI',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None}],
#     '22IR': [{'course_name': 'Kinh tế chính trị Mác - Lênin',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tư tưởng Hồ Chí Minh',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Chương trình dịch',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Kỹ thuật Robot',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Chuyên đề 3 (IT)',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': 'Hệ thống thông minh'},
#      {'course_name': 'Đồ án chuyên ngành 2 (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Điện tử ứng dụng',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Hệ thống thời gian thực',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Linux và phần mềm nguồn mở',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Thực tập doanh nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None}],
#     '22NS': [{'course_name': 'Kinh tế chính trị Mác - Lênin',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tư tưởng Hồ Chí Minh',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Chương trình dịch',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Lập trình Python',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Mật mã học',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Chuyên đề 3 (IT)',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': 'Tấn công và phòng thủ ứng dụng web'},
#      {'course_name': 'Đồ án chuyên ngành 2 (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Kiểm thử xâm nhập',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Thực tập doanh nghiệp (IT)',
#       'lt': 0.0,
#       'th': 3.0,
#       'tong': 3.0,
#       'subnote': None}],
#     '22IRB': [{'course_name': 'Chủ nghĩa xã hội khoa học',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Lịch sử Đảng Cộng sản Việt Nam',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Kỹ thuật Robot',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Chuyên đề 3 (IT)',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': 'Hệ thống thông minh'},
#      {'course_name': 'Đồ án chuyên ngành 2 (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Lập trình Python cho hệ thống nhúng',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Mạng cảm biến không dây',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None}],
#     '22DM': [{'course_name': 'Lịch sử Đảng Cộng sản Việt Nam',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tư tưởng Hồ Chí Minh',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Khởi sự kinh doanh',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Phân tích Marketing số',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Quảng cáo hiển thị và video',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Chuyên đề 1 (BA)',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': 'Trực quan hóa dữ liệu'},
#      {'course_name': 'Chiến lược Digital Marketing',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None}],
#     '22BA': [{'course_name': 'Lịch sử Đảng Cộng sản Việt Nam',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tư tưởng Hồ Chí Minh',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Khởi sự kinh doanh',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'An toàn và bảo mật trong TMĐT',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Thiết kế Website Thương mại điện tử 2',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Quản trị thương hiệu',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Chuyên đề 2 (BA)',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': 'Blockchain trong TMĐT'},
#      {'course_name': 'Quản trị bán hàng',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None}],
#     '22GBA-DM': [{'course_name': 'Lịch sử Đảng Cộng sản Việt Nam',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tư tưởng Hồ Chí Minh',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Khởi sự kinh doanh',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Phân tích Marketing số',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Quảng cáo hiển thị và video',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Chuyên đề 1 (BA)',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': 'Trực quan hóa dữ liệu'},
#      {'course_name': 'Chiến lược Digital Marketing',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None}],
#     '22GBA-BA': [{'course_name': 'Lịch sử Đảng Cộng sản Việt Nam',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tư tưởng Hồ Chí Minh',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Khởi sự kinh doanh',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'An toàn và bảo mật trong TMĐT',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Thiết kế Website Thương mại điện tử 2',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Quản trị thương hiệu',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Chuyên đề 2 (BA)',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': 'Blockchain trong TMĐT'},
#      {'course_name': 'Quản trị bán hàng',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None}],
#     '22ET': [{'course_name': 'Lịch sử Đảng Cộng sản Việt Nam',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tư tưởng Hồ Chí Minh',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Khởi sự kinh doanh',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Quản trị chất lượng dịch vụ du lịch',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Thanh toán quốc tế trong du lịch',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Nghiệp vụ hướng dẫn du lịch',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Chuyên đề 2 (BA)',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': 'Du lịch bền vững'}],
#     '22EL1': [{'course_name': 'Lịch sử Đảng cộng sản Việt Nam',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tư tưởng Hồ Chí Minh',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Khởi sự kinh doanh',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Thực hành mô phỏng trong Logistics',
#       'lt': 0.0,
#       'th': 2.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'An toàn và bảo mật trong E-logistics',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Khai phá và lưu trữ dữ liệu Logistics',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Chiến lược kinh doanh điện tử',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None}],
#     '22EL2': [{'course_name': 'Lịch sử Đảng cộng sản Việt Nam',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tư tưởng Hồ Chí Minh',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Khởi sự kinh doanh',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Thực hành mô phỏng trong Logistics',
#       'lt': 0.0,
#       'th': 2.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'An toàn và bảo mật trong E-logistics',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Khai phá và lưu trữ dữ liệu Logistics',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Chiến lược kinh doanh điện tử',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None}],
#     '22EF': [{'course_name': 'Lịch sử Đảng Cộng sản Việt Nam',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tư tưởng Hồ Chí Minh',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Khởi sự kinh doanh',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đầu tư tài chính',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Hệ thống thanh toán quốc tế',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'An toàn bảo mật thông tin tài chính',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Chuyên đề 2 (BA)',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': 'Đổi mới sáng tạo trong tài chính'}],
#     '22IM': [{'course_name': 'Lịch sử Đảng Cộng Sản Việt Nam',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tư tưởng Hồ Chí Minh',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Khởi sự kinh doanh',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Lập dự án đầu tư',
#       'lt': 2.5,
#       'th': 0.5,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Quản lý rủi ro dự án CNTT',
#       'lt': 2.5,
#       'th': 0.5,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Quản lý dự án Công nghệ thông tin',
#       'lt': 2.5,
#       'th': 0.5,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Công nghệ website',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None}]},
#    23: {'23SE1': [{'course_name': 'Lập trình mạng',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Trí tuệ nhân tạo',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án cơ sở 4 (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Thực tập thực tế (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Anh nâng cao 3',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Linux và phần mềm nguồn mở',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Phân tích và thiết kế giải thuật',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Lập trình hệ thống',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Đồ họa máy tính',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Chuyên đề 2 (IT)',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': 'Xe tự hành'}],
#     '23SE2': [{'course_name': 'Lập trình mạng',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Trí tuệ nhân tạo',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án cơ sở 4 (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Thực tập thực tế (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Anh nâng cao 3',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Linux và phần mềm nguồn mở',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Phân tích và thiết kế giải thuật',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Lập trình hệ thống',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Đồ họa máy tính',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Chuyên đề 2 (IT)',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': 'Xe tự hành'}],
#     '23SE3': [{'course_name': 'Lập trình mạng',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Trí tuệ nhân tạo',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án cơ sở 4 (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Thực tập thực tế (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Anh nâng cao 3',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Linux và phần mềm nguồn mở',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Phân tích và thiết kế giải thuật',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Lập trình hệ thống',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Đồ họa máy tính',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Chuyên đề 2 (IT)',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': 'Xe tự hành'}],
#     '23GIT': [{'course_name': 'Lập trình mạng',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Trí tuệ nhân tạo',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án cơ sở 4 (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Thực tập thực tế (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Anh nâng cao 3',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Linux và phần mềm nguồn mở',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Phân tích và thiết kế giải thuật',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Lập trình hệ thống',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Đồ họa máy tính',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Chuyên đề 2 (IT)',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': 'Lập trình xe tự hành'}],
#     '23JIT-KS': [{'course_name': 'Lập trình mạng',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Trí tuệ nhân tạo',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án cơ sở 4 (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Thực tập thực tế (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Nhật 2',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Linux và phần mềm nguồn mở',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Phân tích và thiết kế giải thuật',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Lập trình hệ thống',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Đồ họa máy tính',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Chuyên đề 2 (IT)',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': 'Khởi nghiệp thực tế'}],
#     '23KIT-KS': [{'course_name': 'Lập trình mạng',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Trí tuệ nhân tạo',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án cơ sở 4 (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Thực tập thực tế (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Hàn doanh nghiệp 1',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Linux và phần mềm nguồn mở',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Phân tích và thiết kế giải thuật',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Lập trình hệ thống',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Đồ họa máy tính',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Chuyên đề 2 (IT)',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': 'PosgresQL'}],
#     '23MC-KS': [{'course_name': 'Lập trình mạng',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Trí tuệ nhân tạo',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án cơ sở 4 (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Thực tập thực tế (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Anh nâng cao 3',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Kỹ thuật chụp ảnh và quay phim',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Xử lý ảnh cơ bản',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Kịch bản truyền thông',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Thiết kế nhân vật 2 chiều',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Chuyên đề 1 (IT)',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': 'Luật phối cảnh'}],
#     '23DA': [{'course_name': 'Xác suất thống kê',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Toán rời rạc',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Lập trình di động',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án cơ sở 4 (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Thực tập thực tế (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Anh nâng cao 3',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Nguyên lý thiết kế đồ họa',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Kỹ thuật chụp ảnh và quay phim',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Nghệ thuật chữ',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Chuyên đề 2 (IT)',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': 'Giải phẫu tạo hình'}],
#     '23GITB': [{'course_name': 'Triết học Mác - Lênin',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Pháp luật đại cương',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Lập trình mạng',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Trí tuệ nhân tạo',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Đồ án cơ sở 4 (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Thực tập thực tế (IT)',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Kho dữ liệu',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None}],
#     '23SE4': [{'course_name': 'Triết học Mác - Lênin',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Pháp luật đại cương',
#       'lt': 2.0,
# ...
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Nhập môn ngành và kỹ năng mềm (IT)',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Lập trình cơ bản',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Giải tích 1',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Giáo dục thể chất 1',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Lập trình hướng đối tượng',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Cơ sở dữ liệu',
#       'lt': 2.5,
#       'th': 0.5,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Anh chuyên ngành 1',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None}],
#     '25MT': [{'course_name': 'Pháp luật đại cương',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Anh 1',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Nhập môn ngành và kỹ năng mềm',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Lập trình cơ bản',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Hình họa 1',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Cơ sở tạo hình 1',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Giải phẫu tạo hình',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Anh chuyên ngành 1 (IT)',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None}],
#     '25DA': [{'course_name': 'Pháp luật đại cương',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Anh 1',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Nhập môn ngành và kỹ năng mềm',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Lập trình cơ bản',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Hình họa 1',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Cơ sở tạo hình 1',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Giải phẫu tạo hình',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Anh chuyên ngành 1 (IT)',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None}],
#     '25GIC': [{'course_name': 'Tiếng Anh 1',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Nhập môn ngành và kỹ năng mềm (CE)',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Lập trình cơ bản',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Giải tích 1',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Giáo dục thể chất 1',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Cơ sở dữ liệu',
#       'lt': 2.5,
#       'th': 0.5,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Lập trình hướng đối tượng',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Cấu kiện điện tử',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Anh chuyên ngành 1 (CE)',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None}],
#     '25GCE': [{'course_name': 'Tiếng Anh 1',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Nhập môn ngành và kỹ năng mềm (CE)',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Lập trình cơ bản',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Giải tích 1',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Giáo dục thể chất 1',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Cơ sở dữ liệu',
#       'lt': 2.5,
#       'th': 0.5,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Lập trình hướng đối tượng',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Cấu kiện điện tử',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Anh chuyên ngành 1 (CE)',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None}],
#     '25AS': [{'course_name': 'Tiếng Anh 1',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Nhập môn ngành và kỹ năng mềm (CE)',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Lập trình cơ bản',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Giải tích 1',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Giáo dục thể chất 1',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Cơ sở dữ liệu',
#       'lt': 2.5,
#       'th': 0.5,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Lập trình hướng đối tượng',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Cấu kiện điện tử',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Anh chuyên ngành 1 (CE)',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None}],
#     '25CE-CN': [{'course_name': 'Tiếng Anh 1',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Lập trình cơ bản',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Giải tích 1',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Giáo dục thể chất 1',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Cơ sở dữ liệu',
#       'lt': 2.5,
#       'th': 0.5,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Lập trình hướng đối tượng',
#       'lt': 2.0,
#       'th': 1.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Cấu kiện điện tử',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Anh chuyên ngành 1 (CE)',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None}],
#     '25NS': [{'course_name': 'Tiếng Anh 1',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Nhập môn ngành và kỹ năng mềm (IT)',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Lập trình cơ bản',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Giải tích 1',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Giáo dục thể chất 1',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Cơ sở dữ liệu',
#       'lt': 2.5,
#       'th': 0.5,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Kiến trúc máy tính',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Anh chuyên ngành 1 (IT)',
#       'lt': 1.0,
#       'th': 1.0,
#       'tong': 2.0,
#       'subnote': None}],
#     '25GBA': [{'course_name': 'Tin học đại cương',
#       'lt': 2.5,
#       'th': 0.5,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Pháp luật đại cương',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Anh 1',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Nhập môn ngành & kỹ năng mềm (BA)',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Giáo dục thể chất 1',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Quản trị học',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Kinh tế vi mô',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Anh chuyên ngành 1 (BA)',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None}],
#     '25GEL': [{'course_name': 'Tin học đại cương',
#       'lt': 2.5,
#       'th': 0.5,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Pháp luật đại cương',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Anh 1',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Nhập môn ngành & kỹ năng mềm (BA)',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Giáo dục thể chất 1',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Quản trị học',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Kinh tế vi mô',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Anh chuyên ngành 1 (BA)',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None}],
#     '25EL': [{'course_name': 'Tin học đại cương',
#       'lt': 2.5,
#       'th': 0.5,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Pháp luật đại cương',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Anh 1',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Nhập môn ngành & kỹ năng mềm (BA)',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Giáo dục thể chất 1',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Quản trị học',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Kinh tế vi mô',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Anh chuyên ngành 1 (BA)',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None}],
#     '25ET': [{'course_name': 'Tin học đại cương',
#       'lt': 2.5,
#       'th': 0.5,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Pháp luật đại cương',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Anh 1',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Nhập môn ngành & kỹ năng mềm (BA)',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Giáo dục thể chất 1',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Quản trị học',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Kinh tế vi mô',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Anh chuyên ngành 1 (BA)',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None}],
#     '25IM': [{'course_name': 'Tin học đại cương',
#       'lt': 2.5,
#       'th': 0.5,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Pháp luật đại cương',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Anh 1',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Nhập môn ngành & kỹ năng mềm (BA)',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Giáo dục thể chất 1',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Quản trị học',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Kinh tế vi mô',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Anh chuyên ngành 1 (BA)',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None}],
#     '25GDM': [{'course_name': 'Tin học đại cương',
#       'lt': 2.5,
#       'th': 0.5,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Anh 1',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Pháp luật đại cương',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Giáo dục thể chất 1',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Nhập môn ngành & kỹ năng mềm (BA)',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Quản trị học',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Kinh tế vi mô',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Anh chuyên ngành 1',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None}],
#     '25DM': [{'course_name': 'Tin học đại cương',
#       'lt': 2.5,
#       'th': 0.5,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Anh 1',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Pháp luật đại cương',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Giáo dục thể chất 1',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Nhập môn ngành & kỹ năng mềm (BA)',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Quản trị học',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Kinh tế vi mô',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Anh chuyên ngành 1',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None}],
#     '25EF': [{'course_name': 'Tin học ứng dụng trong kinh doanh',
#       'lt': 2.5,
#       'th': 0.5,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Pháp luật đại cương',
#       'lt': 2.0,
#       'th': 0.0,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Tiếng Anh 1',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Nhập môn ngành & kỹ năng mềm (BA)',
#       'lt': 1.5,
#       'th': 0.5,
#       'tong': 2.0,
#       'subnote': None},
#      {'course_name': 'Giáo dục thể chất 1',
#       'lt': 0.0,
#       'th': 1.0,
#       'tong': 1.0,
#       'subnote': None},
#      {'course_name': 'Kinh tế vi mô',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Marketing căn bản',
#       'lt': 3.0,
#       'th': 0.0,
#       'tong': 3.0,
#       'subnote': None},
#      {'course_name': 'Lập trình Python (BA)',
#       'lt': 2.5,
#       'th': 0.5,
#       'tong': 3.0,
#       'subnote': None}]}}}}

# %% [markdown]
# ### Save results

# %%
import json
df.to_csv('../ingest_data/cleaned/cleaned_data_hoc_phan.csv', index=False, encoding='utf-8-sig') 
with open('../ingest_data/cleaned/data_hoc_phan.json', 'w', encoding='utf-8') as f:
    # Dùng json.dump để ghi dictionary vào file
    json.dump(result, f, indent=4, ensure_ascii=False)

print("Đã lưu file data_hoc_phan.json thành công!")
# Out:
# Đã lưu file data_hoc_phan.json thành công!
